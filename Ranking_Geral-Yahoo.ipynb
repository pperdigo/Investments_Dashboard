# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas_datareader.data as web
from datetime import datetime, date, timedelta
import yfinance as yf

# %% [markdown]
# # Adquirindo dados

# %%
acoes = open("tickers.txt", "r", encoding="utf8").read().splitlines()
dados = pd.DataFrame()
end = datetime.today()
start = end - timedelta(450)
end = end.strftime("%Y-%m-%d")
start = start.strftime("%Y-%m-%d")
dados = yf.download(tickers = acoes, start = start, end = end)['Adj Close']
dados = dados.tail(260)
dados
# Out:
# [*********************100%***********************]  256 of 256 completed
#
# 15 Failed downloads:
# - DTEX3.SA: No data found, symbol may be delisted
# - TESA3.SA: No data found, symbol may be delisted
# - OMGE3.SA: No data found, symbol may be delisted
# - JBDU3.SA: No data found, symbol may be delisted
# - HGTX3.SA: No data found, symbol may be delisted
# - BTOW3.SA: No data found, symbol may be delisted
# - CCPR3.SA: No data found, symbol may be delisted
# - IGTA3.SA: No data found, symbol may be delisted
# - LINX3.SA: No data found, symbol may be delisted
# - JBDU4.SA: No data found, symbol may be delisted
# - PNVL4.SA: No data found, symbol may be delisted
# - BSEV3.SA: No data found, symbol may be delisted
# - BRDT3.SA: No data found, symbol may be delisted
# - SMLS3.SA: No data found, symbol may be delisted
# - VVAR3.SA: No data found, symbol may be delisted
#              AALR3.SA   ABCB4.SA   ABEV3.SA  AFLT3.SA   AGRO3.SA   ALPA3.SA  \
# Date
# 2021-03-02   9.020000  14.841883  13.464525  8.723467  20.785202  30.045929
# 2021-03-03   8.820000  14.747707  13.637765  8.501274  20.848848  30.095350
# 2021-03-04   8.920000  14.747707  14.224853  8.646182  20.776110  30.994751
# 2021-03-05   9.460000  15.058483  14.513584  8.675163  21.230730  31.133120
# 2021-03-08   8.940000  14.248584  14.138233  8.655844  20.912495  28.662237
# ...               ...        ...        ...       ...        ...        ...
# 2022-03-10  17.549999  15.960000  13.380000  9.290000  33.590000  20.400000
# 2022-03-11  17.440001  15.760000  13.180000  9.000000  33.029999  19.200001
# 2022-03-01        NaN        NaN        NaN       NaN        NaN        NaN
# 2021-04-02        NaN        NaN        NaN       NaN        NaN        NaN
# 2021-05-02        NaN        NaN        NaN       NaN        NaN        NaN
#
#              ALPA4.SA  ALUP11.SA  ALUP3.SA  ALUP4.SA  ...  VIVR3.SA  \
# Date                                                  ...
# 2021-03-02  35.069180  22.437765  7.691463  7.439194  ...      0.94
# 2021-03-03  35.138405  22.379663  7.643089  7.400448  ...      0.94
# 2021-03-04  35.702122  22.960699  7.884959  7.691041  ...      0.93
# 2021-03-05  36.394409  23.357744  7.952683  7.749160  ...      0.93
# 2021-03-08  33.002213  22.883228  7.875285  7.555431  ...      0.90
# ...               ...        ...       ...       ...  ...       ...
# 2022-03-10  23.440001  25.610001  8.490000  8.520000  ...      0.93
# 2022-03-11  22.090000  25.430000  8.520000  8.560000  ...      0.87
# 2022-03-01        NaN        NaN       NaN       NaN  ...       NaN
# 2021-04-02        NaN        NaN       NaN       NaN  ...       NaN
# 2021-05-02        NaN        NaN       NaN       NaN  ...       NaN
#
#              VIVT3.SA   VLID3.SA  VULC3.SA  VVAR3.SA   WEGE3.SA  WHRL3.SA  \
# BBDC3.SA     1.000750
#                ...
# CEAB3.SA     0.999435
# EUCA3.SA     0.998879
# BMGB4.SA     0.999466
# CAMB3.SA     1.000073
# ^BVSP        1.000695
# Name: Retornos diários médios, Length: 231, dtype: float64

# %% [markdown]
# ## Retornos mínimos e máximos

# %%
ret_min = pd.Series(dtype = float)
ret_max = pd.Series(dtype = float)
ret_min.reindex_like(retornos_diarios_med)
ret_max.reindex_like(retornos_diarios_med)
for a in acoes:
    ret_min[a] = retornos_diarios[a].min()-1
    ret_max[a] = retornos_diarios[a].max()-1
ret_min = ret_min.rename("Retorno Mínimo")
ret_max = ret_max.rename("Retorno Máximo")

# %% [markdown]
# ## Retorno acumulado

# %%
ret_acum=dados.iloc[-1]/dados.iloc[0]
ret_acum=ret_acum.rename("Retorno líquido acumulado")

# %% [markdown]
# ## Dataframe de Retorno

# %%
retorno = pd.DataFrame()
retorno = retorno.append(retornos_diarios_med)
retorno = retorno.append(ret_min)
retorno = retorno.append(ret_max)
retorno = retorno.append(ret_acum)
del retorno['^BVSP']
retorno
# Out:
#                            ALPA4.SA  ALUP11.SA  ABEV3.SA  BBSE3.SA  BBDC3.SA  \
# Retornos diários médios    1.002491   1.000314  1.001254  0.998860  1.000750
# Retorno Mínimo            -0.093207  -0.026815 -0.055710 -0.042468 -0.060199
# Retorno Máximo             0.166537   0.047059  0.088829  0.042230  0.091052
# Retorno líquido acumulado  1.763482   1.063277  1.309739  0.720972  1.152710
#
#                            BBDC4.SA  BBAS3.SA  BRSR6.SA  SANB11.SA  B3SA3.SA  \
# Retornos diários médios    1.001021  1.000119  0.999928   1.001813  0.998980
# Retorno Mínimo            -0.065587 -0.116457 -0.064419  -0.043431 -0.077076
# Retorno Máximo             0.094988  0.072483  0.068992   0.090700  0.063683
# Retorno líquido acumulado  1.233325  0.979418  0.939966   1.502664  0.718864
#
#                            ...  EMAE4.SA  MWET4.SA  VIVA3.SA  TCNO3.SA  \
# Retornos diários médios    ...  1.005108  1.005714  1.001851  1.003101
# Retorno Mínimo             ... -0.102363 -0.101523 -0.070363 -0.323116
# Retorno Máximo             ...  0.196984  0.325553  0.098861  0.333333
# Retorno líquido acumulado  ...  3.260574  2.997143  1.495269  1.491453
#
#                            TCNO4.SA  PCAR3.SA  CEAB3.SA  EUCA3.SA  BMGB4.SA  \
# Retornos diários médios    1.003886  1.006510  0.999435  0.998879  0.999466
# Retorno Mínimo            -0.294586 -0.073976 -0.107178 -0.066543 -0.082243
# Retorno Máximo             0.391045  1.122839  0.114191  0.166667  0.083491
# Retorno líquido acumulado  1.812500  3.390535  0.765349  0.684610  0.806996
#
#                            CAMB3.SA
# Retornos diários médios    1.000073
# Retorno Mínimo            -0.114583
# Retorno Máximo             0.152882
# Retorno líquido acumulado  0.914286
#
# [4 rows x 230 columns]

# %% [markdown]
# # Métricas de Risco

# %% [markdown]
# ## Calculando a semivariância

# %%
def f_semivariancia (retornos_diarios, media):
    tamanho=len(retornos_diarios)
    somatorio = 0
    #print('Média: ' + str(media))                                   // para debug
    #print('Retorno no dia 1: ' + str(retornos_diarios.iloc[1]))     // para debug
    t = 0
    while t in range(tamanho):
        dif = (retornos_diarios.iloc[t] - media)
        #print('Dif = ' + str(retornos_diarios.iloc[t] - media))    // para debug
        if dif < 0:
            somatorio += dif ** 2
        t += 1
    med = somatorio / tamanho
    semivariancia = med ** (0.5)
    return (semivariancia)

# %%
semivariancia = []
for a in acoes:
    semivariancia.append(f_semivariancia(retornos_diarios[a],retornos_diarios_med.loc[a]))
semivariancia
semivariancia = pd.Series(semivariancia)
semivariancia.index = acoes
semivariancia = semivariancia.rename('Semivariância')
semivariancia
# Out:
# ALPA4.SA     0.015498
# ALUP11.SA    0.008130
# ABEV3.SA     0.013751
# BBSE3.SA     0.010977
# BBDC3.SA     0.013391
#                ...
# CEAB3.SA     0.020896
# EUCA3.SA     0.016169
# BMGB4.SA     0.015636
# CAMB3.SA     0.019447
# ^BVSP        0.009619
# Name: Semivariância, Length: 231, dtype: float64

# %% [markdown]
# ## Calculando desvio padrão

# %%
desvio_padrao = retornos_diarios.std()
desvio_padrao = desvio_padrao.rename('Desvio Padrão')
desvio_padrao
# Out:
# ALPA4.SA     0.024759
# ALUP11.SA    0.012483
# ABEV3.SA     0.020689
# BBSE3.SA     0.015679
# BBDC3.SA     0.020152
#                ...
# CEAB3.SA     0.030660
# EUCA3.SA     0.026421
# BMGB4.SA     0.024367
# CAMB3.SA     0.029121
# ^BVSP        0.013028
# Name: Desvio Padrão, Length: 231, dtype: float64

# %% [markdown]
# ## Calculando beta de mercado

# %%
cov = retornos_diarios.cov()
cov
# Out:
#            ALPA4.SA  ALUP11.SA  ABEV3.SA  BBSE3.SA  BBDC3.SA  BBDC4.SA  \
# ALPA4.SA   0.000613   0.000077  0.000096  0.000097  0.000061  0.000051
# ALUP11.SA  0.000077   0.000156  0.000081  0.000072  0.000079  0.000074
# ABEV3.SA   0.000096   0.000081  0.000428  0.000172  0.000251  0.000259
# BBSE3.SA   0.000097   0.000072  0.000172  0.000246  0.000187  0.000177
# BBDC3.SA   0.000061   0.000079  0.000251  0.000187  0.000406  0.000404
# ...             ...        ...       ...       ...       ...       ...
# CEAB3.SA   0.000193   0.000128  0.000193  0.000218  0.000224  0.000210
# EUCA3.SA  -0.000020  -0.000010  0.000059  0.000062  0.000074  0.000076
# BMGB4.SA   0.000071   0.000071  0.000168  0.000127  0.000211  0.000218
# CAMB3.SA   0.000066   0.000027  0.000102  0.000070  0.000086  0.000097
# ^BVSP      0.000099   0.000067  0.000173  0.000144  0.000202  0.000200
#
#            BBAS3.SA  BRSR6.SA  SANB11.SA  B3SA3.SA  ...  MWET4.SA  VIVA3.SA  \
# ALPA4.SA   0.000069  0.000077   0.000042  0.000168  ...  0.000090  0.000197
# ALUP11.SA  0.000072  0.000074   0.000061  0.000072  ...  0.000092  0.000077
# ABEV3.SA   0.000220  0.000177   0.000232  0.000142  ...  0.000057  0.000192
# BBSE3.SA   0.000168  0.000148   0.000169  0.000162  ...  0.000078  0.000186
# BBDC3.SA   0.000332  0.000258   0.000366  0.000175  ...  0.000039  0.000200
# ...             ...       ...        ...       ...  ...       ...       ...
# CEAB3.SA   0.000182  0.000146   0.000150  0.000223  ...  0.000176  0.000365
# EUCA3.SA   0.000062  0.000022   0.000059 -0.000005  ...  0.000093  0.000054
# BMGB4.SA   0.000212  0.000203   0.000199  0.000159  ...  0.000113  0.000258
# CAMB3.SA   0.000098  0.000115   0.000068  0.000159  ...  0.000058  0.000114
# ^BVSP      0.000196  0.000149   0.000187  0.000185  ...  0.000042  0.000164
#
#            TCNO3.SA  TCNO4.SA  PCAR3.SA  CEAB3.SA  EUCA3.SA  BMGB4.SA  \
# ALPA4.SA   0.000080  0.000023  0.000163  0.000193 -0.000020  0.000071
# ALUP11.SA  0.000055  0.000005  0.000051  0.000128 -0.000010  0.000071
# ABEV3.SA   0.000109  0.000120  0.000050  0.000193  0.000059  0.000168
# BBSE3.SA   0.000106  0.000062  0.000015  0.000218  0.000062  0.000127
# BBDC3.SA   0.000132  0.000096 -0.000057  0.000224  0.000074  0.000211
# ...             ...       ...       ...       ...       ...       ...
# CEAB3.SA   0.000211  0.000150 -0.000025  0.000940  0.000057  0.000259
# EUCA3.SA   0.000040  0.000128  0.000019  0.000057  0.000698  0.000089
# BMGB4.SA   0.000080  0.000095  0.000021  0.000259  0.000089  0.000594
# CAMB3.SA   0.000036  0.000053 -0.000180  0.000182 -0.000023  0.000159
# ^BVSP      0.000112  0.000062  0.000113  0.000193  0.000037  0.000156
#
#            CAMB3.SA     ^BVSP
# ALPA4.SA   0.000066  0.000099
# ALUP11.SA  0.000027  0.000067
# ABEV3.SA   0.000102  0.000173
# BBSE3.SA   0.000070  0.000144
# BBDC3.SA   0.000086  0.000202
# ...             ...       ...
# CEAB3.SA   0.000182  0.000193
# EUCA3.SA  -0.000023  0.000037
# BMGB4.SA   0.000159  0.000156
# CAMB3.SA   0.000848  0.000095
# ^BVSP      0.000095  0.000170
#
# [231 rows x 231 columns]

# %%
beta = []
for a in acoes:
    beta.append(cov.loc[a, '^BVSP']/retornos_diarios['^BVSP'].var())
beta = pd.Series(beta)
beta.index = acoes
beta = beta.rename('Beta de mercado')
beta
# Out:
# ALPA4.SA     0.582512
# ALUP11.SA    0.394262
# ABEV3.SA     1.017290
# BBSE3.SA     0.846855
# BBDC3.SA     1.193019
#                ...
# CEAB3.SA     1.134798
# EUCA3.SA     0.220409
# BMGB4.SA     0.919320
# CAMB3.SA     0.562187
# ^BVSP        1.000000
# Name: Beta de mercado, Length: 231, dtype: float64

# %% [markdown]
# ## Calculando Downside Risk

# %%
def f_downside (retornos_diarios_acao, retornos_diarios_bovespa):
    tamanho=len(retornos_diarios)
    t = 0
    dif = (retornos_diarios_acao - retornos_diarios_bovespa)
    while t in range(tamanho):
        if dif.iloc[t] > 0:
            dif.iloc[t] = 0
        t += 1
    dif = dif ** 2
    media = dif.mean()
    Downside_Risk = media ** (0.5)
    return (Downside_Risk)

# %%
Downside_Risk = []
for a in acoes:
    Downside_Risk.append(f_downside(retornos_diarios[a],retornos_diarios['^BVSP']))
Downside_Risk = pd.Series(Downside_Risk)
Downside_Risk.index = acoes
Downside_Risk = Downside_Risk.rename('Downside Risk')
Downside_Risk
# Out:
# ALPA4.SA     0.014186
# ALUP11.SA    0.009389
# ABEV3.SA     0.009702
# BBSE3.SA     0.009063
# BBDC3.SA     0.008167
#                ...
# CEAB3.SA     0.018989
# EUCA3.SA     0.018613
# BMGB4.SA     0.014010
# CAMB3.SA     0.018911
# ^BVSP        0.000000
# Name: Downside Risk, Length: 231, dtype: float64

# %% [markdown]
# ## Calcular TEV

# %%
TE = retornos_diarios.sub(retornos_diarios['^BVSP'], axis=0)
TEV = TE.std()
TEV.rename("Tracking Error Volatility", inplace = True)
TEV
# Out:
# ALPA4.SA     0.024186
# ALUP11.SA    0.013846
# ABEV3.SA     0.015889
# BBSE3.SA     0.011318
# BBDC3.SA     0.013071
#                ...
# CEAB3.SA     0.026918
# EUCA3.SA     0.028160
# BMGB4.SA     0.021246
# CAMB3.SA     0.028756
# ^BVSP        0.000000
# Name: Tracking Error Volatility, Length: 231, dtype: float64

# %%
TE
# Out:
#             ALPA4.SA  ALUP11.SA  ABEV3.SA  BBSE3.SA  BBDC3.SA  BBDC4.SA  \
# Date
# 2020-08-11       NaN        NaN       NaN       NaN       NaN       NaN
# 2020-08-12 -0.002969  -0.011647  0.005768  0.001932 -0.004402 -0.008605
# 2020-08-13  0.039462   0.003058 -0.003803 -0.018493 -0.013127 -0.004559
# 2020-08-14 -0.017215  -0.011381 -0.005094 -0.011093 -0.000678 -0.007464
# 2020-08-17  0.015606   0.000205 -0.013575 -0.011871 -0.009091 -0.011859
# ...              ...        ...       ...       ...       ...       ...
# 2021-08-25 -0.003327  -0.000677 -0.005618  0.006474 -0.008027 -0.003339
# 2021-08-26  0.013204   0.010209 -0.009403 -0.010900 -0.002579 -0.001883
# 2021-08-27 -0.007996  -0.017654 -0.020549 -0.010852 -0.003762 -0.003398
# 2021-08-30  0.039456   0.021739  0.015989 -0.014528 -0.000753 -0.002971
# 2021-08-31 -0.000587  -0.002573 -0.008156  0.006277  0.019796  0.015779
#
#             BBAS3.SA  BRSR6.SA  SANB11.SA  B3SA3.SA  ...  MWET4.SA  VIVA3.SA  \
# Date                                                 ...
# 2020-08-11       NaN       NaN        NaN       NaN  ...       NaN       NaN
# 2020-08-12 -0.004757 -0.007091  -0.000119  0.011396  ... -0.009452 -0.006178
# 2020-08-13 -0.003922 -0.018063  -0.020168  0.002405  ...  0.004682 -0.006798
# 2020-08-14 -0.005553 -0.021198  -0.000910 -0.010198  ...  0.013019  0.007757
# 2020-08-17 -0.008273 -0.009801  -0.000874 -0.023434  ...  0.010202 -0.022655
# ...              ...       ...        ...       ...  ...       ...       ...
# 2021-08-25 -0.008317 -0.008296  -0.001185  0.001425  ... -0.061406  0.020815
# 2021-08-26  0.003233  0.008374   0.006263 -0.006256  ...  0.023350 -0.008488
# 2021-08-27 -0.001161 -0.000846  -0.003320 -0.001817  ... -0.042689  0.009734
# 2021-08-30 -0.001726 -0.001936  -0.000633 -0.003771  ... -0.021055  0.016585
# 2021-08-31  0.020416  0.029170   0.028427  0.014444  ...  0.021500 -0.000931
#
#             TCNO3.SA  TCNO4.SA  PCAR3.SA  CEAB3.SA  EUCA3.SA  BMGB4.SA  \
# Date
# 2020-08-11       NaN       NaN       NaN       NaN       NaN       NaN
# 2020-08-12 -0.042187 -0.068202 -0.030665 -0.068417 -0.026820 -0.020051
# 2020-08-13  0.007298  0.022938  0.006956 -0.019004  0.011897  0.020050
# 2020-08-14 -0.044915 -0.015546 -0.002283  0.025765 -0.008879 -0.001260
# 2020-08-17 -0.001346 -0.009500 -0.008561 -0.063198 -0.004394 -0.012900
# ...              ...       ...       ...       ...       ...       ...
# 2021-08-25  0.001086  0.035392  0.009159 -0.032910 -0.008946  0.026276
# 2021-08-26  0.145381  0.158675 -0.015357 -0.034869  0.021243 -0.001360
# 2021-08-27 -0.048891 -0.069090 -0.010251  0.006220 -0.009965 -0.011696
# 2021-08-30  0.010566 -0.037979  0.014284 -0.030242  0.040031  0.017252
# 2021-08-31 -0.027280 -0.006274 -0.018152 -0.000523  0.000575 -0.018204
#
#             CAMB3.SA  ^BVSP
# Date
# 2020-08-11       NaN    NaN
# 2020-08-12 -0.019232    0.0
# 2020-08-13  0.002773    0.0
# 2020-08-14 -0.020243    0.0
# 2020-08-17 -0.035528    0.0
# ...              ...    ...
# 2021-08-25 -0.078734    0.0
# 2021-08-26 -0.055395    0.0
# 2021-08-27 -0.028713    0.0
# 2021-08-30  0.020180    0.0
# 2021-08-31  0.020183    0.0
#
# [260 rows x 231 columns]

# %% [markdown]
# ## Calcular Drawdown

# %%
RBA = pd.DataFrame()
serie_unit = []
tamanho_dias = len(retornos_diarios)
a = 0
while a in range(len(acoes)):
    serie_unit.append(1)
    a += 1
serie_unit = pd.Series(serie_unit)
serie_unit.index = acoes
RBA = RBA.reindex_like(retornos_diarios, method = 'backfill')
RBA.iloc[0] = serie_unit
for a in acoes:
    t=1
    while t in range(tamanho_dias):
        RBA[a].iloc[t]=RBA[a].iloc[t-1]*retornos_diarios[a].iloc[t]
        t+=1
RBA
# Out:
#             ALPA4.SA  ALUP11.SA  ABEV3.SA  BBSE3.SA  BBDC3.SA  BBDC4.SA  \
# Date
# 2020-08-11  1.000000   1.000000  1.000000  1.000000  1.000000  1.000000
# 2020-08-12  0.996483   0.987805  1.005220  1.001384  0.995049  0.990847
# 2020-08-13  1.019637   0.974797  0.985086  0.966616  0.965842  0.970252
# 2020-08-14  1.011137   0.972358  0.988814  0.964476  0.973762  0.971625
# 2020-08-17  1.009379   0.955691  0.958240  0.936298  0.948020  0.943249
# ...              ...        ...       ...       ...       ...       ...
# 2021-08-25  1.703986   1.060759  1.352038  0.750332  1.149277  1.235964
# 2021-08-26  1.696952   1.053203  1.315891  0.729148  1.126395  1.212215
# 2021-08-27  1.711313   1.051943  1.310508  0.733236  1.140696  1.228048
# 2021-08-30  1.765534   1.066635  1.321275  0.716884  1.130971  1.214854
# 2021-08-31  1.763482   1.063277  1.309739  0.720972  1.152710  1.233325
#
#             BBAS3.SA  BRSR6.SA  SANB11.SA  B3SA3.SA  ...  MWET4.SA  VIVA3.SA  \
# Date                                                 ...
# 2020-08-11  1.000000  1.000000   1.000000  1.000000  ...  1.000000  1.000000
# 2020-08-12  0.994695  0.992361   0.999333  1.010848  ...  0.990000  0.993274
# 2020-08-13  0.974654  0.958333   0.962963  0.996877  ...  0.978571  0.970404
# 2020-08-14  0.977896  0.946528   0.970637  0.995562  ...  1.000000  0.986547
# 2020-08-17  0.952844  0.920833   0.952953  0.954964  ...  0.992857  0.947085
# ...              ...       ...        ...       ...  ...       ...       ...
# 2021-08-25  0.968620  0.916821   1.471506  0.724039  ...  3.085714  1.484894
# 2021-08-26  0.954964  0.908609   1.455219  0.706960  ...  3.104286  1.446554
# 2021-08-27  0.969573  0.922794   1.474339  0.717311  ...  3.022857  1.484443
# 2021-08-30  0.960363  0.913835   1.461946  0.709030  ...  2.935714  1.497524
# 2021-08-31  0.979418  0.939966   1.502664  0.718864  ...  2.997143  1.495269
#
#             TCNO3.SA  TCNO4.SA  PCAR3.SA  CEAB3.SA  EUCA3.SA  BMGB4.SA  \
# Date
# 2020-08-11  1.000000   1.00000  1.000000  1.000000  1.000000  1.000000
# 2020-08-12  0.957265   0.93125  0.968787  0.931034  0.972632  0.979401
# 2020-08-13  0.948718   0.93750  0.959806  0.898234  0.968421  0.983146
# 2020-08-14  0.914530   0.93125  0.966137  0.929352  0.968421  0.990637
# 2020-08-17  0.897436   0.90625  0.941107  0.854500  0.947368  0.960674
# ...              ...       ...       ...       ...       ...       ...
# 2021-08-25  1.401709   1.76875  3.527004  0.821699  0.656370  0.826302
# 2021-08-26  1.581197   2.01875  3.411711  0.778806  0.658937  0.810857
# 2021-08-27  1.529915   1.91250  3.432888  0.796468  0.663216  0.814718
# 2021-08-30  1.534188   1.82500  3.455240  0.766190  0.684610  0.822441
# 2021-08-31  1.491453   1.81250  3.390535  0.765349  0.684610  0.806996
#
#             CAMB3.SA     ^BVSP
# Date
# 2020-08-11  1.000000  1.000000
# 2020-08-12  0.980220  0.999452
# 2020-08-13  0.967033  0.983234
# 2020-08-14  0.956044  0.991965
# 2020-08-17  0.905494  0.974759
# ...              ...       ...
# 2021-08-25  0.967033  1.182473
# 2021-08-26  0.896703  1.161979
# 2021-08-27  0.885714  1.181103
# 2021-08-30  0.896703  1.171922
# 2021-08-31  0.914286  1.171248
#
# [260 rows x 231 columns]

# %%
drawdown = pd.DataFrame()
drawdown = drawdown.reindex_like(retornos_diarios, method = 'backfill')
#min(RBA['WEGE3.SA'].tail(tamanho_dias-200))
for a in acoes:
    t=0
    while t in range(tamanho_dias):
        drawdown[a].iloc[t]=(RBA[a].iloc[t]-min(RBA[a].tail(tamanho_dias-t)))/RBA[a].iloc[t]
        t+=1
drawdown_max = []
for a in acoes:
    drawdown_max.append(max(drawdown[a]))
drawdown_max = pd.Series(drawdown_max)
drawdown_max.index = acoes
drawdown_max = drawdown_max.rename('Drawdown')
drawdown_max
# Out:
# ALPA4.SA     0.223412
# ALUP11.SA    0.161770
# ABEV3.SA     0.176451
# BBSE3.SA     0.335805
# BBDC3.SA     0.191012
#                ...
# CEAB3.SA     0.410843
# EUCA3.SA     0.411334
# BMGB4.SA     0.377207
# CAMB3.SA     0.350000
# ^BVSP        0.120262
# Name: Drawdown, Length: 231, dtype: float64

# %% [markdown]
# ## Criando dataframe de risco

# %%
risco = pd.DataFrame()
risco = risco.append(desvio_padrao)
risco = risco.append(semivariancia)
risco = risco.append(drawdown_max)
risco = risco.append(Downside_Risk)
risco = risco.append(TEV)
risco = risco.append(beta)
del risco['^BVSP']
risco
# Out:
#                            ALPA4.SA  ALUP11.SA  ABEV3.SA  BBSE3.SA  BBDC3.SA  \
# Desvio Padrão              0.024759   0.012483  0.020689  0.015679  0.020152
# Semivariância              0.015498   0.008130  0.013751  0.010977  0.013391
# Drawdown                   0.223412   0.161770  0.176451  0.335805  0.191012
# Downside Risk              0.014186   0.009389  0.009702  0.009063  0.008167
# Tracking Error Volatility  0.024186   0.013846  0.015889  0.011318  0.013071
# Beta de mercado            0.582512   0.394262  1.017290  0.846855  1.193019
#
#                            BBDC4.SA  BBAS3.SA  BRSR6.SA  SANB11.SA  B3SA3.SA  \
# Desvio Padrão              0.020662  0.019946  0.018343   0.022067  0.022547
# Semivariância              0.013478  0.014159  0.012484   0.013827  0.015648
# Drawdown                   0.199856  0.289076  0.186827   0.188134  0.343113
# Downside Risk              0.008533  0.009129  0.010434   0.009759  0.013481
# Tracking Error Volatility  0.013989  0.013226  0.014408   0.016821  0.017550
# Beta de mercado            1.181180  1.156691  0.879639   1.101060  1.090339
#
#                            ...  EMAE4.SA  MWET4.SA  VIVA3.SA  TCNO3.SA  \
# Desvio Padrão              ...  0.033311  0.056056  0.024539  0.057097
# Semivariância              ...  0.019641  0.031154  0.016260  0.032641
# Drawdown                   ...  0.327193  0.491211  0.254922  0.660281
# Downside Risk              ...  0.017662  0.028302  0.012933  0.030818
# Tracking Error Volatility  ...  0.033393  0.056823  0.021088  0.056622
# Beta de mercado            ...  0.483895  0.244985  0.963882  0.659010
#
#                            TCNO4.SA  PCAR3.SA  CEAB3.SA  EUCA3.SA  BMGB4.SA  \
# Desvio Padrão              0.058442  0.074839  0.030660  0.026421  0.024367
# Semivariância              0.031400  0.019044  0.020896  0.016169  0.015636
# Drawdown                   0.687898  0.309701  0.410843  0.411334  0.377207
# Downside Risk              0.030035  0.014479  0.018989  0.018613  0.014010
# Tracking Error Volatility  0.058827  0.074462  0.026918  0.028160  0.021246
# Beta de mercado            0.367064  0.665503  1.134798  0.220409  0.919320
#
#                            CAMB3.SA
# Desvio Padrão              0.029121
# Semivariância              0.019447
# Drawdown                   0.350000
# Downside Risk              0.018911
# Tracking Error Volatility  0.028756
# Beta de mercado            0.562187
#
# [6 rows x 230 columns]

# %%
media_dp = risco.loc['Desvio Padrão'].mean()
dp_dp = risco.loc['Desvio Padrão'].std()
media_sv = risco.loc['Semivariância'].mean()
dp_sv = risco.loc['Semivariância'].std()
media_drd = risco.loc['Drawdown'].mean()
dp_drd = risco.loc['Drawdown'].std()
media_dsr = risco.loc['Downside Risk'].mean()
dp_dsr = risco.loc['Downside Risk'].std()
media_tev = risco.loc['Tracking Error Volatility'].mean()
dp_tev = risco.loc['Tracking Error Volatility'].std()
media_beta = risco.loc['Beta de mercado'].mean()
dp_beta = risco.loc['Beta de mercado'].std()

# %%
risco_norm = pd.DataFrame()
dp_norm = (risco.loc['Desvio Padrão'] - media_dp) / dp_dp
dp_norm = dp_norm.rename('Desvio Padrão Normalizado')
risco_norm = risco_norm.append(dp_norm)
sv_norm = (risco.loc['Semivariância'] - media_sv) / dp_sv
sv_norm = sv_norm.rename('Semivariância Normalizada')
risco_norm = risco_norm.append(sv_norm)
drd_norm = (risco.loc['Drawdown'] - media_drd) / dp_drd
drd_norm = drd_norm.rename('Drawdown Normalizado')
risco_norm = risco_norm.append(drd_norm)
dsr_norm = (risco.loc['Downside Risk'] - media_dsr) / dp_dsr
dsr_norm = dsr_norm.rename('Downside Risk Normalizado')
risco_norm = risco_norm.append(dsr_norm)
tev_norm = (risco.loc['Tracking Error Volatility'] - media_tev) / dp_tev
tev_norm = tev_norm.rename('Tracking Error Volatility Normalizado')
risco_norm = risco_norm.append(tev_norm)
beta_norm = (risco.loc['Beta de mercado'] - media_beta) / dp_beta
beta_norm = beta_norm.rename('Beta de mercado Normalizado')
risco_norm = risco_norm.append(beta_norm)
risco_norm
# Out:
#                                        ALPA4.SA  ALUP11.SA  ABEV3.SA  \
# Desvio Padrão Normalizado             -0.284184  -1.105680 -0.556491
# Semivariância Normalizada             -0.355875  -1.401743 -0.603817
# Drawdown Normalizado                  -0.675054  -1.111138 -1.007279
# Downside Risk Normalizado             -0.310980  -1.030218 -0.983234
# Tracking Error Volatility Normalizado -0.181438  -0.853041 -0.720347
# Beta de mercado Normalizado           -0.645791  -1.221415  0.683663
#
#                                        BBSE3.SA  BBDC3.SA  BBDC4.SA  BBAS3.SA  \
# Desvio Padrão Normalizado             -0.891773 -0.592470 -0.558332 -0.606251
# Semivariância Normalizada             -0.997682 -0.654990 -0.642687 -0.545952
# Drawdown Normalizado                   0.120070 -0.904266 -0.841699 -0.210513
# Downside Risk Normalizado             -1.078984 -1.213361 -1.158540 -1.069190
# Tracking Error Volatility Normalizado -1.017227 -0.903372 -0.843753 -0.893311
# Beta de mercado Normalizado            0.162512  1.221001  1.184801  1.109920
#
#                                        BRSR6.SA  SANB11.SA  B3SA3.SA  ...  \
# Desvio Padrão Normalizado             -0.713543  -0.464293 -0.432164  ...
# Semivariância Normalizada             -0.783750  -0.593061 -0.334532  ...
# Drawdown Normalizado                  -0.933871  -0.924629  0.171774  ...
# Downside Risk Normalizado             -0.873515  -0.974655 -0.416720  ...
# Tracking Error Volatility Normalizado -0.816556  -0.659839 -0.612484  ...
# Beta de mercado Normalizado            0.262756   0.939811  0.907030  ...
#
#                                        EMAE4.SA  MWET4.SA  VIVA3.SA  TCNO3.SA  \
# Desvio Padrão Normalizado              0.288105  1.810221 -0.298889  1.879837
# Semivariância Normalizada              0.232213  1.866556 -0.247666  2.077704
# Drawdown Normalizado                   0.059145  1.219484 -0.452137  2.415568
# Downside Risk Normalizado              0.210193  1.805399 -0.498750  2.182613
# Tracking Error Volatility Normalizado  0.416492  1.938282 -0.382691  1.925213
# Beta de mercado Normalizado           -0.947339 -1.677872  0.520351 -0.411876
#
#                                        TCNO4.SA  PCAR3.SA  CEAB3.SA  EUCA3.SA  \
# Desvio Padrão Normalizado              1.969877  3.067108  0.110740 -0.172943
# Semivariância Normalizada              1.901558  0.147492  0.410387 -0.260567
# Drawdown Normalizado                   2.610945 -0.064605  0.650922  0.654401
# Downside Risk Normalizado              2.065177 -0.266988  0.409170  0.352776
# Tracking Error Volatility Normalizado  2.068422  3.083919 -0.004040  0.076629
# Beta de mercado Normalizado           -1.304581 -0.392022  1.042973 -1.753018
#
#                                        BMGB4.SA  CAMB3.SA
# Desvio Padrão Normalizado             -0.310411  0.007734
# Semivariância Normalizada             -0.336299  0.204726
# Drawdown Normalizado                   0.412968  0.220492
# Downside Risk Normalizado             -0.337406  0.397391
# Tracking Error Volatility Normalizado -0.372403  0.115364
# Beta de mercado Normalizado            0.384092 -0.707940
#
# [6 rows x 230 columns]

# %%
risco_norm['ABEV3.SA']
# Out:
# Desvio Padrão Normalizado               -0.556491
# Semivariância Normalizada               -0.603817
# Drawdown Normalizado                    -1.007279
# Downside Risk Normalizado               -0.983234
# Tracking Error Volatility Normalizado   -0.720347
# Beta de mercado Normalizado              0.683663
# Name: ABEV3.SA, dtype: float64

# %% [markdown]
# ## Criar ranking de risco

# %%
nota_risco = []
t=0
for a in (acoes_sem_bvsp):
    nota_risco.append(risco_norm[a].mean())
nota_risco = pd.Series(nota_risco)
nota_risco.index = acoes_sem_bvsp
nota_risco = nota_risco.sort_values(ascending = False)
nota_risco
# Out:
# JBDU3.SA     3.148313
# VIVR3.SA     2.989310
# JBDU4.SA     2.730346
# IGBR3.SA     2.725475
# FHER3.SA     2.692845
#                ...
# ALUP11.SA   -1.120539
# WHRL3.SA    -1.154599
# TAEE11.SA   -1.173712
# TAEE3.SA    -1.174025
# BEES3.SA    -1.204428
# Length: 230, dtype: float64

# %%
ranking_risco = []
t=0
while t in range(len(nota_risco)):
    ranking_risco.append(t+1)
    t+=1
ranking_risco = pd.Series(ranking_risco)
ranking_risco.index = nota_risco.index
ranking_risco
# Out:
# JBDU3.SA       1
# VIVR3.SA       2
# JBDU4.SA       3
# IGBR3.SA       4
# FHER3.SA       5
#             ...
# ALUP11.SA    226
# WHRL3.SA     227
# TAEE11.SA    228
# TAEE3.SA     229
# BEES3.SA     230
# Length: 230, dtype: int64

# %% [markdown]
# # Métricas de performance

# %% [markdown]
# ## Calcular Sharpe

# %%
#Várias métricas para Risk Free
ret_poup = 0.0072217938876129/100

CDI = 4.15/100
ret_nu = (1+CDI)**(1/360)-1

#Definir qual é o Risk Free
risk_free = ret_nu

# %%
sharpe = []
for a in acoes:
    sharpe.append((retornos_diarios_med[a]-1-risk_free)/desvio_padrao[a])
sharpe = pd.Series(sharpe)
sharpe.index = acoes
sharpe = sharpe.rename('Índice de Sharpe')
sharpe
# Out:
# ALPA4.SA     0.096039
# ALUP11.SA    0.016120
# ABEV3.SA     0.055144
# BBSE3.SA    -0.079900
# BBDC3.SA     0.031603
#                ...
# CEAB3.SA    -0.022101
# EUCA3.SA    -0.046722
# BMGB4.SA    -0.026562
# CAMB3.SA    -0.001368
# ^BVSP        0.044702
# Name: Índice de Sharpe, Length: 231, dtype: float64

# %% [markdown]
# ## Calcular Sortino (semivariância)

# %%
sortino_sv = []
for a in acoes:
    sortino_sv.append((retornos_diarios_med[a]-1-risk_free)/semivariancia[a])
sortino_sv = pd.Series(sortino_sv)
sortino_sv.index = acoes
sortino_sv = sortino_sv.rename('Sortino (semivariância)')
sortino_sv
# Out:
# ALPA4.SA     0.153427
# ALUP11.SA    0.024748
# ABEV3.SA     0.082966
# BBSE3.SA    -0.114129
# BBDC3.SA     0.047559
#                ...
# CEAB3.SA    -0.032429
# EUCA3.SA    -0.076345
# BMGB4.SA    -0.041395
# CAMB3.SA    -0.002049
# ^BVSP        0.060547
# Name: Sortino (semivariância), Length: 231, dtype: float64

# %% [markdown]
# ## Calcular Sortino (Downside Risk)

# %%
sortino_dsr = []
for a in acoes:
    sortino_dsr.append((retornos_diarios_med[a]-retornos_diarios_med['^BVSP'])/Downside_Risk[a])
sortino_dsr = pd.Series(sortino_dsr)
sortino_dsr.index = acoes
sortino_dsr = sortino_dsr.rename('Sortino (Downside Risk)')
sortino_dsr
# Out:
# <ipython-input-33-bd5fc9f26ccd>:3: RuntimeWarning: invalid value encountered in double_scalars
#   sortino_dsr.append((retornos_diarios_med[a]-retornos_diarios_med['^BVSP'])/Downside_Risk[a])
# ALPA4.SA     0.126564
# ALUP11.SA   -0.040598
# ABEV3.SA     0.057568
# BBSE3.SA    -0.202479
# BBDC3.SA     0.006670
#                ...
# CEAB3.SA    -0.066354
# EUCA3.SA    -0.097611
# BMGB4.SA    -0.087770
# CAMB3.SA    -0.032903
# ^BVSP             NaN
# Name: Sortino (Downside Risk), Length: 231, dtype: float64

# %% [markdown]
# ## Calcular Treynor

# %%
Treynor = []
for a in acoes:
    Treynor.append((retornos_diarios_med[a]-1-risk_free)/beta[a])
Treynor = pd.Series(Treynor)
Treynor.index = acoes
Treynor = Treynor.rename('Índice de Treynor')
Treynor
# Out:
# ALPA4.SA     0.004082
# ALUP11.SA    0.000510
# ABEV3.SA     0.001122
# BBSE3.SA    -0.001479
# BBDC3.SA     0.000534
#                ...
# CEAB3.SA    -0.000597
# EUCA3.SA    -0.005601
# BMGB4.SA    -0.000704
# CAMB3.SA    -0.000071
# ^BVSP        0.000582
# Name: Índice de Treynor, Length: 231, dtype: float64

# %% [markdown]
# ## Calcular Calmar

# %%
Calmar = []
for a in acoes:
    Calmar.append((retornos_diarios_med[a]-1-risk_free)/drawdown_max[a])
Calmar = pd.Series(Calmar)
Calmar.index = acoes
Calmar = Calmar.rename('Índice de Calmar')
Calmar
# Out:
# ALPA4.SA     0.010643
# ALUP11.SA    0.001244
# ABEV3.SA     0.006466
# BBSE3.SA    -0.003731
# BBDC3.SA     0.003334
#                ...
# CEAB3.SA    -0.001649
# EUCA3.SA    -0.003001
# BMGB4.SA    -0.001716
# CAMB3.SA    -0.000114
# ^BVSP        0.004843
# Name: Índice de Calmar, Length: 231, dtype: float64

# %% [markdown]
# ## Calcular Information Ratio

# %%
InfRatio = []
for a in acoes:
    InfRatio.append((retornos_diarios_med[a]-retornos_diarios_med['^BVSP'])/TEV[a])
InfRatio = pd.Series(InfRatio)
InfRatio.index = acoes
InfRatio = InfRatio.rename('Information Ratio')
InfRatio
# Out:
# <ipython-input-36-9c53ffdc9d93>:3: RuntimeWarning: invalid value encountered in double_scalars
#   InfRatio.append((retornos_diarios_med[a]-retornos_diarios_med['^BVSP'])/TEV[a])
# ALPA4.SA     0.074233
# ALUP11.SA   -0.027529
# ABEV3.SA     0.035152
# BBSE3.SA    -0.162145
# BBDC3.SA     0.004168
#                ...
# CEAB3.SA    -0.046809
# EUCA3.SA    -0.064518
# BMGB4.SA    -0.057875
# CAMB3.SA    -0.021638
# ^BVSP             NaN
# Name: Information Ratio, Length: 231, dtype: float64

# %% [markdown]
# ## Calcular M2

# %%
M2 = []
for a in acoes:
    M2.append(sharpe[a]*desvio_padrao['^BVSP']+risk_free)
M2 = pd.Series(M2)
M2.index = acoes
M2 = M2.rename('M2')
M2
# Out:
# ALPA4.SA     0.001364
# ALUP11.SA    0.000323
# ABEV3.SA     0.000831
# BBSE3.SA    -0.000928
# BBDC3.SA     0.000525
#                ...
# CEAB3.SA    -0.000175
# EUCA3.SA    -0.000496
# BMGB4.SA    -0.000233
# CAMB3.SA     0.000095
# ^BVSP        0.000695
# Name: M2, Length: 231, dtype: float64

# %% [markdown]
# ## DataFrame de performance

# %%
perf = pd.DataFrame()
perf = perf.append(sharpe)
perf = perf.append(sortino_sv)
perf = perf.append(sortino_dsr)
perf = perf.append(Treynor)
perf = perf.append(Calmar)
perf = perf.append(InfRatio)
perf = perf.append(M2)
del perf['^BVSP']

# %%
media_sharpe = perf.loc['Índice de Sharpe'].mean()
dp_sharpe = perf.loc['Índice de Sharpe'].std()
media_sort_sv = perf.loc['Sortino (semivariância)'].mean()
dp_sort_sv = perf.loc['Sortino (semivariância)'].std()
media_sort_dsr = perf.loc['Sortino (Downside Risk)'].mean()
dp_sort_dsr = perf.loc['Sortino (Downside Risk)'].std()
media_treynor = perf.loc['Índice de Treynor'].mean()
dp_treynor = perf.loc['Índice de Treynor'].std()
media_calmar = perf.loc['Índice de Calmar'].mean()
dp_calmar = perf.loc['Índice de Calmar'].std()
media_ir = perf.loc['Information Ratio'].mean()
dp_ir = perf.loc['Information Ratio'].std()
media_m2 = perf.loc['M2'].mean()
dp_m2 = perf.loc['M2'].std()

# %%
perf_norm = pd.DataFrame()
#sharpe
sharpe_norm = (perf.loc['Índice de Sharpe'] - media_sharpe) / dp_sharpe
sharpe_norm = sharpe_norm.rename('Sharpe Normalizado')
perf_norm = perf_norm.append(sharpe_norm)
#sortino sv
ssv_norm = (perf.loc['Sortino (semivariância)'] - media_sort_sv) / dp_sort_sv
ssv_norm = ssv_norm.rename('Sortino (semivariância) Normalizado')
perf_norm = perf_norm.append(ssv_norm)
#sortino dsr
sdsr_norm = (perf.loc['Sortino (Downside Risk)'] - media_sort_dsr) / dp_sort_dsr
sdsr_norm = sdsr_norm.rename('Sortino (Downside Risk) Normalizado')
perf_norm = perf_norm.append(sdsr_norm)
#Treynor
treynor_norm = (perf.loc['Índice de Treynor'] - media_treynor) / dp_treynor
treynor_norm = treynor_norm.rename('Treynor Normalizado')
perf_norm = perf_norm.append(treynor_norm)
#Calmar
calmar_norm = (perf.loc['Índice de Calmar'] - media_calmar) / dp_calmar
calmar_norm = calmar_norm.rename('Calmar Normalizado')
perf_norm = perf_norm.append(calmar_norm)
#IR
ir_norm = (perf.loc['Information Ratio'] - media_ir) / dp_ir
ir_norm = ir_norm.rename('Information Ratio Normalizado')
perf_norm = perf_norm.append(ir_norm)
#M2
m2_norm = (perf.loc['M2'] - media_m2) / dp_m2
m2_norm = sharpe_norm.rename('M2 Normalizado')
perf_norm = perf_norm.append(m2_norm)
#dataframe normalizado
perf_norm
# Out:
#                                      ALPA4.SA  ALUP11.SA  ABEV3.SA  BBSE3.SA  \
# Sharpe Normalizado                   1.009416  -0.261373  0.359150 -1.788166
# Sortino (semivariância) Normalizado  1.006212  -0.290169  0.296354 -1.689303
# Sortino (Downside Risk) Normalizado  0.903567  -0.557795  0.300389 -1.972985
# Treynor Normalizado                  0.350318  -0.311563 -0.198306 -0.680283
# Calmar Normalizado                   0.912175  -0.425837  0.317526 -1.133963
# Information Ratio Normalizado        0.963828  -0.517245  0.395029 -2.476486
# M2 Normalizado                       1.009416  -0.261373  0.359150 -1.788166
#
#                                      BBDC3.SA  BBDC4.SA  BBAS3.SA  BRSR6.SA  \
# Sharpe Normalizado                  -0.015175  0.181072 -0.512806 -0.677670
# Sortino (semivariância) Normalizado -0.060364  0.139228 -0.535143 -0.688434
# Sortino (Downside Risk) Normalizado -0.144566  0.130720 -0.754733 -0.845462
# Treynor Normalizado                 -0.307215 -0.263686 -0.405160 -0.445020
# Calmar Normalizado                  -0.128282  0.043834 -0.599883 -0.743515
# Information Ratio Normalizado       -0.055921  0.222188 -0.750716 -0.891315
# M2 Normalizado                      -0.015175  0.181072 -0.512806 -0.677670
#
#                                      SANB11.SA  B3SA3.SA  ...  EMAE4.SA  \
# Sharpe Normalizado                    0.707117 -1.316857  ...  1.866504
# Sortino (semivariância) Normalizado   0.698983 -1.269083  ...  2.022472
# Sortino (Downside Risk) Normalizado   0.798078 -1.315444  ...  1.981056
# Treynor Normalizado                  -0.120054 -0.598746  ...  1.506652
# Calmar Normalizado                    0.683252 -1.073053  ...  1.570125
# Information Ratio Normalizado         0.850278 -1.539362  ...  1.806526
# M2 Normalizado                        0.707117 -1.316857  ...  1.866504
#
#                                      MWET4.SA  VIVA3.SA  TCNO3.SA  TCNO4.SA  \
# Sharpe Normalizado                   1.071134  0.608860  0.314364  0.508981
# Sortino (semivariância) Normalizado  1.271826  0.537673  0.382651  0.671181
# Sortino (Downside Risk) Normalizado  1.347381  0.578610  0.479452  0.725943
# Treynor Normalizado                  3.830837 -0.071888  0.434023  1.498924
# Calmar Normalizado                   1.020318  0.367928  0.041236  0.177969
# Information Ratio Normalizado        1.168903  0.681378  0.501699  0.672916
# M2 Normalizado                       1.071134  0.608860  0.314364  0.508981
#
#                                      PCAR3.SA  CEAB3.SA  EUCA3.SA  BMGB4.SA  \
# Sharpe Normalizado                   0.841486 -0.869114 -1.260611 -0.940051
# Sortino (semivariância) Normalizado  2.844672 -0.866206 -1.308647 -0.956533
# Sortino (Downside Risk) Normalizado  3.307860 -0.782954 -1.056206 -0.970174
# Treynor Normalizado                  1.375194 -0.516800 -1.444049 -0.536611
# Calmar Normalizado                   2.337479 -0.837688 -1.030110 -0.847157
# Information Ratio Normalizado        1.019952 -0.797859 -1.055604 -0.958908
# M2 Normalizado                       0.841486 -0.869114 -1.260611 -0.940051
#
#                                      CAMB3.SA
# Sharpe Normalizado                  -0.539439
# Sortino (semivariância) Normalizado -0.560138
# Sortino (Downside Risk) Normalizado -0.490521
# Treynor Normalizado                 -0.419272
# Calmar Normalizado                  -0.619101
# Information Ratio Normalizado       -0.431500
# M2 Normalizado                      -0.539439
#
# [7 rows x 230 columns]

# %%
perf_norm['ABEV3.SA']
# Out:
# Sharpe Normalizado                     0.359150
# Sortino (semivariância) Normalizado    0.296354
# Sortino (Downside Risk) Normalizado    0.300389
# Treynor Normalizado                   -0.198306
# Calmar Normalizado                     0.317526
# Information Ratio Normalizado          0.395029
# M2 Normalizado                         0.359150
# Name: ABEV3.SA, dtype: float64

# %% [markdown]
# ## Criar ranking de performance

# %%
nota_perf = []
t=0
for a in (acoes_sem_bvsp):
    nota_perf.append(perf_norm[a].mean())
nota_perf = pd.Series(nota_perf)
nota_perf.index = acoes_sem_bvsp
nota_perf = nota_perf.sort_values(ascending = False)
nota_perf.head(10)
# Out:
# UNIP3.SA    3.603409
# CRPG5.SA    3.551336
# FRAS3.SA    2.733526
# UNIP6.SA    2.404263
# JBDU3.SA    2.322911
# FESA4.SA    2.090700
# FHER3.SA    1.869005
# EMAE4.SA    1.802834
# PCAR3.SA    1.795447
# JBDU4.SA    1.767518
# dtype: float64

# %%
ranking_perf = []
t=0
while t in range(len(nota_perf)):
    ranking_perf.append(t+1)
    t+=1
ranking_perf = pd.Series(ranking_perf)
ranking_perf.index = nota_perf.index
ranking_perf
# Out:
# UNIP3.SA      1
# CRPG5.SA      2
# FRAS3.SA      3
# UNIP6.SA      4
# JBDU3.SA      5
#            ...
# SAPR4.SA    226
# LAME3.SA    227
# SAPR3.SA    228
# BBSE3.SA    229
# LAME4.SA    230
# Length: 230, dtype: int64

# %% [markdown]
# # Ranking Geral

# %%
base_dados = pd.read_excel('C:/Users/perdi/Investimentos/Dados/Dados_Cadastrais.xlsx', index_col=0)
base_dados["Posição no Ranking de Performance"] = ranking_perf
base_dados["Posição no Ranking de Risco"] = ranking_risco
base_dados["Nota Geral"] = ranking_risco / ranking_perf
base_dados
# Out:
#                                           Nome Completo Tipo da ação  \
# Código de negociação
# ALPA4.SA                                ALPARGATAS S.A.           PN
# ALUP11.SA                       ALUPAR INVESTIMENTO S/A         Unit
# ABEV3.SA                                     AMBEV S.A.           ON
# BTOW3.SA                        B2W - COMPANHIA DIGITAL           ON
# BBSE3.SA               BB SEGURIDADE PARTICIPAÇÕES S.A.           ON
# ...                                                 ...          ...
# PCAR3.SA                 CIA BRASILEIRA DE DISTRIBUICAO           ON
# CEAB3.SA                                      CEA MODAS           ON
# EUCA3.SA              EUCATEX S.A. INDUSTRIA E COMERCIO           ON
# BMGB4.SA                                      BANCO BMG           ON
# CAMB3.SA                                   CAMBUCI S.A.           ON
#
#                      Nacionalidade Nível de governança      Setor Econômico  \
# Código de negociação
# ALPA4.SA                  Nacional     Bovespa Nível 1      Consumo cíclico
# ALUP11.SA                 Nacional     Bovespa Nível 2    Utilidade Pública
# ABEV3.SA                  Nacional          Não consta  Consumo não Cíclico
0
#
#                       Posição no Ranking de Risco  Nota Geral
# Código de negociação
# ALPA4.SA                                    149.0    3.921053
# ALUP11.SA                                   226.0    1.625899
# ABEV3.SA                                    179.0    2.156627
# BTOW3.SA                                      NaN         NaN
# BBSE3.SA                                    188.0    0.820961
# ...                                           ...         ...
# PCAR3.SA                                     26.0    2.888889
# CEAB3.SA                                     51.0    0.281768
# EUCA3.SA                                    114.0    0.542857
# BMGB4.SA                                     97.0    0.500000
# CAMB3.SA                                     82.0    0.543046
#
# [255 rows x 14 columns]

# %% [markdown]
# ## Filtrando ações indesejadas

# %%
base_filtrada = base_dados.copy(deep=True)
#Retirar ações no top 20 de risco e ações em recuperação judicial:
for acao in base_filtrada.index:
    if base_filtrada.loc[acao]['Posição no Ranking de Risco'] <= 20:
        print(f'{acao} entre as 20 mais arriscadas. Retirando ela da base cadastral...')
        base_filtrada.drop(index=acao, inplace=True)
for acao in base_filtrada.index:
    if base_filtrada.loc[acao]['Em Recuperação Judicial'] == "Sim":
        print(f'{acao} está em recuperação judicial. Retirando ela da base cadastral...')
        base_filtrada.drop(index=acao, inplace=True)
# Out:
# LAME3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# LAME4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# PDGR3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# ETER3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# BBRK3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# PMAM3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# VIVR3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# FHER3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# TPIS3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# LUPA3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# ATOM3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# AZEV4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# JBDU4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# RPMG3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# IGBR3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# JBDU3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# RCSL3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# MWET4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# TCNO3.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# TCNO4.SA entre as 20 mais arriscadas. Retirando ela da base cadastral...
# OIBR3.SA está em recuperação judicial. Retirando ela da base cadastral...
# OIBR4.SA está em recuperação judicial. Retirando ela da base cadastral...
# OSXB3.SA está em recuperação judicial. Retirando ela da base cadastral...

# %% [markdown]
# ## Filtro de segmento

# %%
filtro_seg=base_filtrada.sort_values(by="Nota Geral",ascending=False).copy(deep=True)    
filtro_seg.reset_index(inplace=True)
i=0
while i in filtro_seg.index:
    segmento=filtro_seg.loc[i]['Segmento']
    #print(i)
    #print('ação atual')
    #print(base_rankeada.iloc[i]['Código de negociação'])
    #print('ações seguintes')
    j=i+1
    while j in range(len(filtro_seg.index)):
        #print(j)
        #print(base_rankeada.iloc[j]['Código de negociação'])
        if filtro_seg.loc[j]['Segmento'] == segmento:
            #print(str(base_rankeada.loc[i]['Código de negociação']))
            #print(str(base_rankeada.loc[j]['Código de negociação']))
            filtro_seg.drop([j], inplace=True)
            filtro_seg.reset_index(drop = True, inplace=True)
            #print(range(len(base_rankeada.index)))
        j+=1
    i+=1
    #print('acabou o loop da ' + str(base_rankeada.loc[i]['Código de negociação']))
filtro_seg.set_index('Código de negociação', inplace=True)

# %% [markdown]
# ## Top 20 após filtragem

# %%
#Gráfico de RBA do top 20 provisório
RBA_top20 = pd.DataFrame()
for acao in base_filtrada.sort_values(by="Nota Geral",ascending=False).head(20).index:
    RBA_top20[acao]=RBA[acao]
RBA_top20.plot(figsize=(15,10), colormap='winter')
plt.show()
#Gráfico de correlação do top 20 provisório
ret_filtro = retornos_diarios.copy(deep=True)
for acao in ret_filtro.columns:
    if acao not in filtro_seg.sort_values(by="Nota Geral",ascending=False).head(20).index:
        ret_filtro.drop(columns=acao,inplace=True)
plt.figure(figsize=(16,8))
sns.heatmap(ret_filtro.corr(), annot =True, cmap="Wistia")
plt.show()
#Dados cadastrais do top 20 provisório
filtro_seg.sort_values(
    by="Nota Geral",ascending=False).head(20).drop(
    columns=['Nacionalidade','Participação (%) no IBOVESPA','Em Recuperação Judicial'])
# Out:
#                                                       Nome Completo  \
# Código de negociação
# UNIP3.SA                                     UNIPAR CARBOCLORO S.A.
# CRPG5.SA                           CRISTAL PIGMENTOS DO BRASIL S.A.
# FRAS3.SA                                               FRAS-LE S.A.
# FESA4.SA                         CIA FERRO LIGAS DA BAHIA - FERBASA
0
#
#                       Posição no Ranking de Risco  Nota Geral
# Código de negociação
# UNIP3.SA                                    218.0  218.000000
# CRPG5.SA                                    178.0   89.000000
# FRAS3.SA                                    210.0   70.000000
# FESA4.SA                                    120.0   20.000000
# EMAE4.SA                                     81.0   10.125000
# TAEE3.SA                                    229.0    9.541667
# VALE3.SA                                    184.0    7.360000
# SLCE3.SA                                    172.0    5.212121
# ARZZ3.SA                                    185.0    5.138889
# BIDI11.SA                                    45.0    4.090909
# WHRL4.SA                                    225.0    4.017857
# ALPA4.SA                                    149.0    3.921053
# SHUL4.SA                                    145.0    3.717949
# PTBL3.SA                                     44.0    3.666667
# RANI3.SA                                    117.0    3.656250
# BRAP3.SA                                    169.0    3.595745
# EMBR3.SA                                     56.0    3.500000
# JBSS3.SA                                    193.0    3.163934
# PCAR3.SA                                     26.0    2.888889
# USIM5.SA                                     75.0    2.777778

# %% [markdown]
# ## Preview dos ativos selecionados

# %%
RBA_top20 = pd.DataFrame()
for acao in top20.head(20).index:
    RBA_top20[acao]=RBA[acao]
RBA_top20.plot(figsize=(16,10), colormap='winter')
plt.show()
ret_top20 = retornos_diarios.copy(deep=True)
for acao in ret_top20.columns:
    if acao not in top20.head(20).index:
        ret_top20.drop(columns=acao,inplace=True)
plt.figure(figsize=(16,10))
sns.heatmap(ret_top20.corr(), annot =True, cmap="Wistia")
plt.show()

# %% [markdown]
# # Exportar resultados da análise

# %%
top20_final=top20.head(20)
top20_final
# Out:
#                                                       Nome Completo  \
# Código de negociação
# UNIP3.SA                                     UNIPAR CARBOCLORO S.A.
# CRPG5.SA                           CRISTAL PIGMENTOS DO BRASIL S.A.
# FRAS3.SA                                               FRAS-LE S.A.
# FESA4.SA                         CIA FERRO LIGAS DA BAHIA - FERBASA
# EMAE4.SA                   EMAE - EMPRESA METROP.AGUAS ENERGIA S.A.
# TAEE3.SA              TRANSMISSORA ALIANÇA DE ENERGIA ELÉTRICA S.A.
# VALE3.SA                                                  VALE S.A.
# SLCE3.SA                                          SLC AGRICOLA S.A.
# ARZZ3.SA                           AREZZO INDÚSTRIA E COMÉRCIO S.A.
# BIDI11.SA                                          BANCO INTER S.A.
# WHRL4.SA                                             WHIRLPOOL S.A.
# ALPA4.SA                                            ALPARGATAS S.A.
# SHUL4.SA                                                SCHULZ S.A.
# PTBL3.SA                                            PORTOBELLO S.A.
# RANI3.SA                                        CELULOSE IRANI S.A.
# BRAP3.SA                                             BRADESPAR S.A.
# EMBR3.SA                                               EMBRAER S.A.
# JBSS3.SA                                                   JBS S.A.
# PCAR3.SA                             CIA BRASILEIRA DE DISTRIBUICAO
# USIM5.SA                   USINAS SID DE MINAS GERAIS S.A.-USIMINAS
#
#                      Tipo da ação Nacionalidade Nível de governança  \
# Código de negociação
# UNIP3.SA                       ON      Nacional          Não consta
# CRPG5.SA                      PNA      Nacional          Não consta
# FRAS3.SA                       ON      Nacional     Bovespa Nível 1
# FESA4.SA                       PN      Nacional     Bovespa Nível 1
# EMAE4.SA                       PN      Nacional          Não consta
# TAEE3.SA                       ON      Nacional     Bovespa Nível 2
# VALE3.SA                       ON      Nacional        Novo Mercado
# SLCE3.SA                       ON      Nacional        Novo Mercado
# ARZZ3.SA                       ON      Nacional        Novo Mercado
# BIDI11.SA                    Unit      Nacional     Bovespa Nível 1
# WHRL4.SA                       PN      Nacional          Não consta
# ALPA4.SA                       PN      Nacional     Bovespa Nível 1
# SHUL4.SA                       PN      Nacional          Não consta
# PTBL3.SA                       ON      Nacional        Novo Mercado
# RANI3.SA                       ON      Nacional          Não consta
# BRAP3.SA                       ON      Nacional     Bovespa Nível 1
# EMBR3.SA                       ON      Nacional        Novo Mercado
# JBSS3.SA                       ON      Nacional        Novo Mercado
# PCAR3.SA                       ON      Nacional     Bovespa Nível 1
# USIM5.SA                      PNA      Nacional     Bovespa Nível 1
#
#                               Setor Econômico                       Subsetor  \
# Código de negociação
